# %%
# Library imports

import tensorflow as tf
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
#from __future__ import print_function
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
import timeit

# %%
# test_data_X = pd.read_excel('TestDataFeatureSelected.xlsx')
# test_data_Y = pd.read_excel('expression_CX-5461.xlsx').T


# test_data_Y.head()
# test_data_Y.iloc[:,-1]
# test_temp = test_data_Y.iloc[:,-1].as_matrix() 
# test_resp = test_temp[1:][:].areshape((len(test_temp[1:][:]), 1))

# print("test_data_X.shape", test_data_X.shape)
# print("test_resp.shape", test_resp.shape)

# test_data = np.append(test_data_X, test_resp, axis = 1)

# print("test_data.shape", test_data.shape)

# # # Generate tain and test data# Gener 
# test_X = test_data_X.as_matrix() 
# test_Y = test_resp

# %%
def shuffle_train_data(X_train, Y_train):
    """called after each epoch"""
    perm = np.random.permutation(len(Y_train))
    Xtr_shuf = X_train[perm]
    Ytr_shuf = Y_train[perm]
    
    return Xtr_shuf, Ytr_shuf

# %%
# # read the data from the excel

# data_X = pd.read_excel('DataFeatureSelected_CX-5461.xlsx')
# data_Y = pd.read_excel('expression_CX-5461.xlsx').T

# print the size of data matrix 
print("data_X.shape", data_X.shape)
print("data_Y.shape", data_Y.shape)
# Out:
# data_X.shape (897, 50)
# data_Y.shape (898, 17738)

# %%
data_Y.iloc[:,-1] # Extracting the response vector
temp = data_Y.iloc[:,-1].as_matrix() # conver
resp = temp[1:][:].reshape((len(temp[1:][:]), 1))

print("data_X.shape", data_X.shape)
print("resp.shape", resp.shape)

data = np.append(data_X, resp, axis = 1)

print("data.shape", data.shape)

# # Generate tain and test data# Gener 
# X = data_X.as_matrix()[200:929][:]
# Y = resp[200:929]

X = data_X.as_matrix()
Y = resp
# X, X_test, Y, Y_test = train_test_split(X, Y)

test_X = data_X.as_matrix()[0:199][:]
test_Y = resp[0:199]

print("X.shape", X.shape)
print("Y.shape", Y.shape)

print("test_X.shape", test_X.shape)
print("test_Y.shape", test_Y.shape)
# Out:
# data_X.shape (897, 50)
# resp.shape (897, 1)
# data.shape (897, 51)
# X.shape (897, 50)
# Y.shape (897, 1)
# test_X.shape (199, 50)
# test_Y.shape (199, 1)

# %%
# for K fold
X_k = np.array([[1, 2], [3, 4], [5, 6], [7, 8]])
y_k = np.array([[1, 2, 3, 4]])
print(X_k.shape)

t_k = np.concatenate((X_k, y_k.T), axis=1)
print(t_k[:,:2])
kf = KFold(n_splits=3)

print(kf.get_n_splits(X_k))
# print(X_k)
for k_train, k_test in kf.split(X_k):  
    print(X_k[k_train].shape, type(X_k[k_train]))
# Out:
# (4, 2)
# [[1 2]
#  [3 4]
#  [5 6]
#  [7 8]]
# 3
# (2, 2) <class 'numpy.ndarray'>
# (3, 2) <class 'numpy.ndarray'>
# (3, 2) <class 'numpy.ndarray'>

# %%
# Parameters
learning_rate = 0.01
training_epochs = 7  #700
batch_size = 9
display_step = 1


# Network Parameters
n_hidden_1 = 50 # 1st layer number of features
n_hidden_2 = 50 # 2nd layer number of features
n_input = 50 # Number of feature
n_classes = 1 # Number of classes to predict


# tf Graph input and output
x = tf.placeholder("float", [None, n_input])
y = tf.placeholder("float", [None, None])

# Create model
def multilayer_perceptron(x, weights, biases):
    
    print("x.shape", x.shape)
    print("weights", weights)
    
    # Hidden layer with RELU activation : changed to sigmoid
    layer_1 = tf.add(tf.matmul(x, weights['w1']), biases['b1'])
    layer_1 = tf.nn.sigmoid(layer_1)
    
    # Hidden layer with RELU activation :  changed to sigmoid
    layer_2 = tf.add(tf.matmul(layer_1, weights['w2']), biases['b2'])
    layer_2 = tf.nn.sigmoid(layer_2)
    
    # Output layer with linear activation 
    out_layer = tf.matmul(layer_2, weights['out']) + biases['out']
    out_layer = tf.nn.sigmoid(out_layer)
    
    return out_layer
    
# Store layers weight & bias
weights = {
    'w1': tf.Variable(tf.random_normal([n_input, n_hidden_1])),
    'w2': tf.Variable(tf.random_normal([n_hidden_1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([n_hidden_2, n_classes]))
}

biases = {
    'b1': tf.Variable(tf.random_normal([1, n_hidden_1])),
    'b2': tf.Variable(tf.random_normal([1, n_hidden_2])),
    'out': tf.Variable(tf.random_normal([1, n_classes]))
}

print("w1", weights['w1'])
print("b1", biases['b1'])
print("w2", weights['w2'])
print("b2", biases['b2'])

# Construct model
pred = multilayer_perceptron(x, weights, biases)
pred_b = pred > 0.5

# Define loss and optimizer
cost = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=pred, labels=y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate).minimize(cost)

# Initializing the variables
init = tf.global_variables_initializer(), tf.local_variables_initializer()
# Out:
# w1 <tf.Variable 'Variable_12:0' shape=(50, 50) dtype=float32_ref>
# b1 <tf.Variable 'Variable_15:0' shape=(1, 50) dtype=float32_ref>
# w2 <tf.Variable 'Variable_13:0' shape=(50, 50) dtype=float32_ref>
# b2 <tf.Variable 'Variable_16:0' shape=(1, 50) dtype=float32_ref>
# x.shape (?, 50)
# weights {'w1': <tf.Variable 'Variable_12:0' shape=(50, 50) dtype=float32_ref>, 'w2': <tf.Variable 'Variable_13:0' shape=(50, 50) dtype=float32_ref>, 'out': <tf.Variable 'Variable_14:0' shape=(50, 1) dtype=float32_ref>}

# %%
data_kv = np.append(X, Y, axis=1)
print(data_kv.shape, type(data_kv))
kf = KFold(n_splits=10)
KV_data = kf.split(data_kv)
# print(kf.get_n_splits(X_k))
# print(data_kv[:,50])
for k_train, k_test in kf.split(data_kv):
#     print(k_train, k_test)
#     print("K train:", k_train[:,50:].shape)
    print(data_kv[k_train][:,50:].shape, type(data_kv[k_train]), len(data_kv[k_train]), data_kv[k_train][1,50:], data_kv[1,1])

accuracy_train = dict()
accuracy_test = dict()
k_count = 1
# Out:
# (897, 51) <class 'numpy.ndarray'>
# (807, 1) <class 'numpy.ndarray'> 807 [0.0] 5.9678209014011
# (807, 1) <class 'numpy.ndarray'> 807 [0.0] 5.9678209014011
# (807, 1) <class 'numpy.ndarray'> 807 [0.0] 5.9678209014011
# (807, 1) <class 'numpy.ndarray'> 807 [0.0] 5.9678209014011
# (807, 1) <class 'numpy.ndarray'> 807 [0.0] 5.9678209014011
# (807, 1) <class 'numpy.ndarray'> 807 [0.0] 5.9678209014011
# (807, 1) <class 'numpy.ndarray'> 807 [0.0] 5.9678209014011
# (808, 1) <class 'numpy.ndarray'> 808 [0.0] 5.9678209014011
# (808, 1) <class 'numpy.ndarray'> 808 [0.0] 5.9678209014011
# (808, 1) <class 'numpy.ndarray'> 808 [0.0] 5.9678209014011

# %%
# Launch the graph

for k_train, k_test in kf.split(data_kv):
    with tf.Session() as sess:
        start = timeit.default_timer()
        sess.run(init)
        # Training cycle
        
        for epoch in range(training_epochs):
            avg_cost = 0
            total_batch = int(len(data_kv[k_train])/batch_size) # batch size is 9, 9 * 93 = 837 
            new_y = data_kv[k_train][:,50:]
            X_batches = np.array_split(data_kv[k_train][:,:50], total_batch)        
            Y_batches = np.array_split(new_y, total_batch)
#             X_batches = np.array_split(X, total_batch)
#             print(X_batches[1], KX_batches[1])
#             Y_batches = np.array_split(Y, total_batch)
            

            # Loop over all batches
            for i in range(total_batch):
                batch_x, batch_y = X_batches[i], Y_batches[i]
#                 print(batch_y.shape)
                # Run optimization op (backprop) and cost op (to get loss value)

                _, c = sess.run([optimizer, cost], feed_dict={x: batch_x,
                                                              y: batch_y})

    #             print("cost c is ", c)
                # Compute average loss
                avg_cost += c / total_batch
            # Display logs per epoch step
            if epoch % display_step == 0:
                print("Epoch:", '%04d' % (epoch+1), "cost=", "{:.9f}".format(avg_cost))
#         print("Optimization Finished!")


        # Training accuracy
        X_train = data_kv[k_train][:,:50]
        Y_train = new_y


        # Test model on training data
        correct_prediction = tf.equal(tf.cast(pred_b, "float"), y)
    #     print("correct prediction", correct_prediction.eval({x: X_train, y: Y_train}))
        # Calculate accuracy
        
#         confusion_matrix = tf.confusion_matrix(pred_b, y)
#         print("Confusion_matrix:", confusion_matrix.eval({x: X_train, y: Y_train}))


        accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float32"))
        print("Train Accuracy:", accuracy.eval({x: X_train, y: Y_train}))
        train_accuracy = accuracy.eval({x: X_train, y: Y_train})
        accuracy_train.update({k_count:train_accuracy})
        # global result 
    #     result = tf.argmax(pred, 1).eval({x: X_train, y: Y_train})


        # Test accuracy
        # Test model on test data

        correct_prediction = tf.equal(tf.cast(pred_b, "float32"), y)
    #     print("correct prediction", correct_prediction.eval({x: test_X, y: test_Y}))
        # Calculate accuracy
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, "float32"))
        new_test_y = data_kv[k_test][:,50:]
        print("Test Accuracy:", accuracy.eval({x: data_kv[k_test][:,:50], y: new_test_y}))
        test_accuracy = accuracy.eval({x: data_kv[k_test][:,:50], y: new_test_y})
        accuracy_test.update({k_count:test_accuracy})
        k_count += 1
        # global result 
    #     result = tf.argmax(pred, 1).eval({x: test_X, y: test_Y})
    
        
        # Sensitivity and Specifity 
        pred_labels = pred_b.eval({x: X_train, y: Y_train})
        pred_labels = pred_labels.astype(int)
        true_labels = Y_train
        TP = np.sum(np.logical_and(pred_labels == 1, true_labels == 1))
        TN = np.sum(np.logical_and(pred_labels == 0, true_labels == 0))
        FP = np.sum(np.logical_and(pred_labels == 1, true_labels == 0))
        FN = np.sum(np.logical_and(pred_labels == 0, true_labels == 1))
        
        sensitivity = TP / (TP + FN)
        specifity = TN / (TN + FP)
        
        # Display sensitivity and specificity
        print('sensitivity:', sensitivity)
        print('specifity', specifity)
        
        stop = timeit.default_timer() # Training time end
        print("Time:", stop - start, "seconds" '\n') # training time display
# Out:
# Epoch: 0001 cost= 0.691232344
# Epoch: 0002 cost= 0.690951596
# Epoch: 0003 cost= 0.690642299
# Epoch: 0004 cost= 0.690295339
# Epoch: 0005 cost= 0.689906077
# Epoch: 0006 cost= 0.689477238
# Epoch: 0007 cost= 0.689010567
# Train Accuracy: 0.366791
# Test Accuracy: 0.966667
# sensitivity: 0.0368217054264
# specifity 0.951890034364
# Time: 1.5185682085138978 seconds
#
# Epoch: 0001 cost= 0.693023767
# Epoch: 0002 cost= 0.693022825
# Epoch: 0003 cost= 0.693021860
# Epoch: 0004 cost= 0.693020874
# Epoch: 0005 cost= 0.693019889
# Epoch: 0006 cost= 0.693018887
# Epoch: 0007 cost= 0.693017860
# Train Accuracy: 0.360595
# Test Accuracy: 1.0
# sensitivity: 0.0
# specifity 1.0
# Time: 1.49112332601635 seconds
#
# Epoch: 0001 cost= 0.649716409
# Epoch: 0002 cost= 0.645491968
# Epoch: 0003 cost= 0.642314699
# Epoch: 0004 cost= 0.639985804
# Epoch: 0005 cost= 0.638184079
# Epoch: 0006 cost= 0.636778559
# Epoch: 0007 cost= 0.635619879
# Train Accuracy: 0.607187
# Test Accuracy: 0.366667
# sensitivity: 0.718992248062
# specifity 0.408934707904
# Time: 1.3954686533047607 seconds
#
# Epoch: 0001 cost= 0.665273195
# Epoch: 0002 cost= 0.664734334
# Epoch: 0003 cost= 0.664074238
# Epoch: 0004 cost= 0.663258023
# Epoch: 0005 cost= 0.662246127
# Epoch: 0006 cost= 0.661003892
# Epoch: 0007 cost= 0.659502916
# Train Accuracy: 0.638166
# Test Accuracy: 0.0111111
# sensitivity: 0.996124031008
# specifity 0.00343642611684
# Time: 1.5301925069297795 seconds
#
# Epoch: 0001 cost= 0.694747313
# Epoch: 0002 cost= 0.688270789
# Epoch: 0003 cost= 0.684266790
# Epoch: 0004 cost= 0.681646185
# Epoch: 0005 cost= 0.679779313
# Epoch: 0006 cost= 0.678327761
# Epoch: 0007 cost= 0.677086375
# Train Accuracy: 0.539033
# Test Accuracy: 0.566667
# sensitivity: 0.391498881432
# specifity 0.722222222222
# Time: 1.7697961517578733 seconds
#
# Epoch: 0001 cost= 0.693142665
# Epoch: 0002 cost= 0.693141199
# Epoch: 0003 cost= 0.693139716
# Epoch: 0004 cost= 0.693138229
# Epoch: 0005 cost= 0.693136728
# Epoch: 0006 cost= 0.693135219
# Epoch: 0007 cost= 0.693133719
# Train Accuracy: 0.472119
# Test Accuracy: 0.0
# sensitivity: 0.0
# specifity 1.0
# Time: 1.8194280696393434 seconds
#
# Epoch: 0001 cost= 0.710513047
# Epoch: 0002 cost= 0.703911934
# Epoch: 0003 cost= 0.699765766
# Epoch: 0004 cost= 0.696985694
# Epoch: 0005 cost= 0.695034163
# Epoch: 0006 cost= 0.693610012
# Epoch: 0007 cost= 0.692525673
# Train Accuracy: 0.479554
# Test Accuracy: 0.0777778
# sensitivity: 0.0704225352113
# specifity 0.937007874016
# Time: 1.876812558734855 seconds
#
# Epoch: 0001 cost= 0.691950735
# Epoch: 0002 cost= 0.691586034
# Epoch: 0003 cost= 0.691226995
# Epoch: 0004 cost= 0.690884170
# Epoch: 0005 cost= 0.690565709
# Epoch: 0006 cost= 0.690273926
# Epoch: 0007 cost= 0.690005888
# Train Accuracy: 0.482673
# Test Accuracy: 0.0449438
# sensitivity: 0.0304449648712
# specifity 0.989501312336
# Time: 1.4990214015310812 seconds
#
# Epoch: 0001 cost= 0.728763115
# Epoch: 0002 cost= 0.709452597
# Epoch: 0003 cost= 0.694516217
# Epoch: 0004 cost= 0.685298503
# Epoch: 0005 cost= 0.679753106
# Epoch: 0006 cost= 0.676260159
# Epoch: 0007 cost= 0.673921582
# Train Accuracy: 0.590347
# Test Accuracy: 0.258427
# sensitivity: 0.391100702576
# specifity 0.813648293963
# Time: 1.5063888786576172 seconds
#
# Epoch: 0001 cost= 0.762131708
# Epoch: 0002 cost= 0.757184455
# Epoch: 0003 cost= 0.750834845
# Epoch: 0004 cost= 0.742729824
# Epoch: 0005 cost= 0.733720097
# Epoch: 0006 cost= 0.725210291
# Epoch: 0007 cost= 0.717253095
# Train Accuracy: 0.518564
# Test Accuracy: 0.674157
# sensitivity: 0.573770491803
# specifity 0.456692913386
# Time: 1.5341309691866627 seconds

# %%
train = "10 Fold Train Accuracy Value: "
test = "10 Fold Test Accuracy Value:  "
for k,v in accuracy_train.items():
    train = train + str(v) + ' '
    test = test + str(accuracy_test[k]) + ' '
print(train)
print(test)

print('Average Test Accurcay: ', sum(accuracy_test.values())/10)
print('Average Train Accuracy: ', sum(accuracy_train.values())/10)
# Out:
# 10 Fold Train Accuracy Value: 0.639405 0.644362 0.372986 0.360595 0.532838 0.472119 0.557621 0.471535 0.527228 0.606436
# 10 Fold Test Accuracy Value:  0.255556 0.0888889 0.955556 1.0 0.488889 0.0 0.544444 0.0 0.247191 0.449438
# Average Test Accurcay:  0.402996257693
# Average Train Accuracy:  0.518512371182
